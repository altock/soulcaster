# %% [markdown]
# ## Defining an E2B template for Sandobox

# %%
from e2b import Template

template = (
    Template()
    .from_ubuntu_image("22.04")
    .set_workdir("/app")
    )
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from e2b import Template
#       3 template = (
#       4     Template()
#       5     .from_ubuntu_image("22.04")
#       6     .set_workdir("/app")
#       7     )
#
# ModuleNotFoundError: No module named 'e2b'

# %%
import e2b
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import e2b
#
# ModuleNotFoundError: No module named 'e2b'
